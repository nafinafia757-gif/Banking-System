# %%
user_name = "Nafia"
pass_word = "250825"

username  =input("Enter username")
password = input("Enter Password")


if username == user_name and password == pass_word:
    print("Login Successful")
    


class Deposit:
    def action(self, balance, amount):
        balance += amount
        return balance, "Amount deposited"


class Withdraw:
    def action(self, balance, amount):
        if amount > balance:
            return balance, "Insufficient balance"
        balance -= amount
        return balance, "Amount withdrawn"



def process(action_obj, balance, amount):
    balance, msg = action_obj.action(balance, amount)
    print(msg)
    return balance



balance = 1000

while True:
    print("\n1.Deposit  2.Withdraw  3.Balance  4.Exit")
    choice = input("Enter choice: ")

    if choice == "1":
        amt = int(input("Enter amount: "))
        d = Deposit()
        balance = process(d, balance, amt)

    elif choice == "2":
        amt = int(input("Enter amount: "))
        w = Withdraw()
        balance = process(w, balance, amt)

    elif choice == "3":
        print("Balance:", balance)

    elif choice == "4":
        print("Thank you!")
        break

    else:
        print("Invalid choice")
# Out:
# Enter username Nafia
# Enter Password 250825
# Login Successful
#
# 1.Deposit  2.Withdraw  3.Balance  4.Exit
# Enter choice:  1
# Enter amount:  12000
# Amount deposited
#
# 1.Deposit  2.Withdraw  3.Balance  4.Exit
# Enter choice:  1
# Enter amount:  12000
# Amount deposited
#
# 1.Deposit  2.Withdraw  3.Balance  4.Exit
# Enter choice:  1
# Enter amount:  1000
# Amount deposited
#
# 1.Deposit  2.Withdraw  3.Balance  4.Exit
# Enter choice:  3
# Balance: 26000
#
# 1.Deposit  2.Withdraw  3.Balance  4.Exit
# Enter choice:  2
# Enter amount:  26000
# Amount withdrawn
#
# 1.Deposit  2.Withdraw  3.Balance  4.Exit
# Enter choice:  3
# Balance: 0
#
# 1.Deposit  2.Withdraw  3.Balance  4.Exit
# Enter choice:  4
# Thank you!
